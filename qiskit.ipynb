# %%
from qiskit import *

# %%
qc = QuantumCircuit(1)

# %%
qc.x(0)

# %%
qc.draw(output='mpl')

# %%
import numpy as np
from qiskit.visualization import plot_bloch_vector
 
# You can use spherical coordinates instead of cartesian.
 
plot_bloch_vector([1, np.pi/2, np.pi/3], coord_type='spherical')

# %%
from qiskit import *
from qiskit_aer import Aer
from qiskit.visualization import plot_bloch_multivector, plot_histogram, visualize_transition

circ = QuantumCircuit(1)
circ.x(0)

simulator = Aer.get_backend('statevector_simulator')
result = simulator.run(circ).result()
sv = result.get_statevector(circ)
ct=result.get_counts()
#comment the lines and view each out put one by one
print(sv)
plot_bloch_multivector(sv)
visualize_transition(circ)
plot_histogram(ct)
# Out:
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))
# /var/folders/t7/b9827pyj3pv54tz_3h5thgj40000gn/T/ipykernel_87435/3529426896.py:15: DeprecationWarning: The function ``qiskit.visualization.transition_visualization.visualize_transition()`` is deprecated as of qiskit 1.2.0. It will be removed in the 2.0 release.
#   visualize_transition(circ)
